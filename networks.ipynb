# %%
# !pip install --upgrade git+git://github.com/networkx/networkx.git#egg=networkx
# Out:
# Successfully installed networkx-2.0.dev20170511104933
# done
# \
# -
# /
# |
# \
# -
# /
# |
# \
# -
#   Running setup.py install for networkx ...
#       Successfully uninstalled networkx-2.0.dev20170511104744
#     Uninstalling networkx-2.0.dev20170511104744:
# Requirement already up-to-date: decorator>=3.4.0 in /opt/conda/envs/python2/lib/python2.7/site-packages (from networkx)
# Installing collected packages: networkx
#   Found existing installation: networkx 2.0.dev20170511104744
# Collecting networkx from git+git://github.com/networkx/networkx.git#egg=networkx
#   Cloning git://github.com/networkx/networkx.git to /tmp/pip-build-enasYQ/networkx

# %%
import networkx as nx
import pandas as pd
from network import *

# %%
c = network_group('c')
ij = network_group('ij')

# %%
nx.draw(ij, with_labels = True)
plt.show()

# %%
nx.draw(c, with_labels = True)
plt.show()

# %%
# create community ID's, assign to each kid...?
# add centrality for each kid???
nx.in_degree_centrality(c)

# closeness centrality doesn't have much variance...
nx.closeness_centrality(c)

# they clearly didn't just pick the kids in the class that was being tested...
# but ij only has 11,
print len(get_out_of_sample_nodes(c))
print len(get_out_of_sample_nodes(ij))
# Out:
# 115 52
# 67
# 52 41
# 11

# %%
# clusters using girvan newman
# these look alright visually!!
get_girvan(c, 1)
get_girvan(ij, 6)
# Out:
# ({291, 293, 295, 296, 298, 300, 301, 304, 307, 308, 310, 311, 312, 313},
#  {292, 294, 303, 305, 314, 315},
#  {297, 316},
#  {299, 302, 309, 317},
#  {306},
#  {318, 319, 320, 322, 325, 326, 327, 329, 333, 336},
#  {321, 323, 324, 328, 330, 331, 332, 335, 337, 338, 339, 340, 341, 342},
#  {334})
